# %%
from keras.layers import Input, Dense 
# from keras.layers import Dropout, BatchNormalization, Reshape
from keras.models import Model
#from keras.regularizers import l2
from keras.utils import plot_model
from keras.callbacks import EarlyStopping
# from sklearn.model_selection import train_test_split
import pickle
import numpy as np
#import seaborn as sns
import matplotlib.pyplot as plt
import os
# from mpl_toolkits.mplot3d import Axes3D
# Out:
# Using TensorFlow backend.

# %%
PATH = '/Users/federicomatteo/Desktop/Kalman_Filter/HDA-project/all_tracks/'
SHAPE = (496, 3)

# %%
def import_data(data_path, shape=None, axis=0):
    """
    Import data stored in a folder identified by its path.
    Return a numpy array containing all the array present in the folder of specified shape 
    stacked along the specified axis. If shape is None, the shape of the first element is used.
    """
    # Init container
    MyData = []
    # Save in a list all files present in the folder
    DirList = os.listdir(data_path)
    
    # Set the shape variable
    if shape == None:
        shape = np.load(data_path + DirList[0]).shape
    
    #
    for j in range(len(DirList)):
        data = np.load(data_path + DirList[j])
        if data.shape == shape:
            MyData.append(data)
        else:
            print('MyData[{}] has invalid shape {}'.format(j, data.shape))
    
    # Stack togheter all the arrays
    data = np.stack(MyData, axis = axis)
        
    return data



def train_val_test_split(data, train=0.7, val=0.2):
    """
    Takes in input an array formatted as (num sequences x dim1 x dim2).
    """
    # Get the total sequences number
    n_sequences = data.shape[0]
    
    # Set indexes to divide the sets
    train_ind = int(n_sequences*train)
    val_ind = train_ind + int(n_sequences*val)
    
    return data[:train_ind], data[train_ind:val_ind], data[val_ind:]



def split(data, width=15, stride=5):
    """
    Divide the sequences stored in input array in frame of assigned width shifted of 'stride'. 
    Return the frames stacked in a new array. If stride equals width, no overlap is created.
    """
    # Get tracks lenght
    track_len = data.shape[1]
    
    data_ = [data[:, start:start+width, :] for start in range(0, track_len-width+1, stride)]
    return np.concatenate(data_, axis=0)



def merge(data, width=15, stride=5): # DA CORREGGERE!!!
    """
    Perform the inverse respect to split(). In case of overlapping return the average of the overlapping values.
    """
    assert stride <= width, "Not defined values when merging frames"
    
    data_list = data[0,:,:,:]
    for i in range(1, prova.shape[0]):
        data_list = np.concatenate((data_list, prova[i,:,:,:]), axis = 0)
    return data_new



def min_max_scale(data):
    """
    Scale separately each component. Data has shape [num_frames, frame_width, num_components].
    """
    # Keep the number of time instants
    frame_width = data.shape[1]
    
    # Compute separately min and max for each component
    min_, max_ = data.min(axis=1), data.max(axis=1)

    # Broadcast min_ and max_ array to the shape of data
    min_ = np.stack([np.tile(x, (frame_width, 1)) for x in min_])
    max_ = np.stack([np.tile(x, (frame_width, 1)) for x in max_])

    # Return normalized data
    return (data - min_) / (max_ - min_)



def test_track(data, model, track_index, frame_width):
    """
    Select one track and compute the denoised version using the specified model
    """
    # Select only one track and add a supplementary dimension on the first axis
    data = np.expand_dims(data[track_index], axis=0)
    # Split data without overlap (with equals stride)
    splitted_data = split(data, width=frame_width, stride=15)
    # Compute the predicted data for each splitted frame
    predicted_data = model.predict(np.expand_dims(splitted_data, axis=3)).squeeze()
    
    # Concatenate the frames and return the array
    return(np.concatenate([frame for frame in predicted_data]))



# split a list of arrays
split_list = lambda lista: [split(x) for x in lista]
scale_list = lambda data: [min_max_scale(x) for x in data]

# %%
from keras.layers import Conv1D, Conv2D, MaxPooling1D, UpSampling1D, Flatten, Reshape
from keras.layers import MaxPooling2D, UpSampling2D, Conv2DTranspose

# -- CNN architecture
# This is the input placeholder
input_seq = Input(shape=(15, 3, 1))

#X = Conv2D(filters = 1, kernel_size=[4,3], padding='valid', activation='tanh', strides=1)(input_seq)
#X = Reshape((12, 1,))(X)

#X = MaxPooling1D(pool_size=2, strides=None)(X)

X = Flatten()(input_seq)

encoded = Dense(20, activation='tanh')(X)

encoded = Dense(20, activation='tanh')(encoded)

encoded = Dense(10, activation='tanh')(encoded)

#X = Dense(, activation='tanh')(encoded)

#X = Reshape((10, 1, 1,))(encoded)

#X = UpSampling2D(size=(2,1))(X)

#decoded = Conv2DTranspose(filters = 1, kernel_size = [4,3], padding='valid', activation='tanh', strides=1)(X)

encoded = Dense(20, activation='tanh')(encoded)

encoded = Dense(20, activation='tanh')(encoded)

decoded = Dense(45, activation='tanh')(encoded)

decoded = Reshape((15, 3, 1,))(decoded)

# This model maps an input to its reconstruction (hopefully denoised)
autoencoder = Model(input_seq, decoded)

autoencoder.compile(optimizer='Nadam', loss= "mean_absolute_error")


# Print architecture information
autoencoder.summary()
# plot_model(autoencoder, show_shapes=True, to_file='FFNN.png', rankdir='LR', show_layer_names=False) #TB o LR
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 15, 3, 1)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 45)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                920
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                220
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_6 (Dense)              (None, 45)                945
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 15, 3, 1)          0
# =================================================================
# Total params: 3,135
# Trainable params: 3,135
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Load data
data = import_data(data_path=PATH, shape=SHAPE)
# Split and scale data
x_train, x_val, x_test = scale_list(train_val_test_split(data))

x_train = split(x_train, width=15, stride=15)
print('Train set shape \t', x_train.shape)

x_val = split(x_val, width=15, stride=15)
print('Validation set shape \t', x_val.shape)

#x_test = split(x_test, width=15, stride=5)
#print('Test set shape \t', x_test.shape)


plt.plot(data[3,:,2])
# Out:
# MyData[78] has invalid shape (459, 3)
# Train set shape 	 (1848, 15, 3)
# Validation set shape 	 (528, 15, 3)

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

history = autoencoder.fit(x_train.reshape((*x_train.shape, 1)), x_train.reshape((*x_train.shape, 1)),
                epochs= 250,
                steps_per_epoch = 100,
                shuffle = True,
                batch_size=None,
                validation_data=(np.expand_dims(x_val, axis=3), np.expand_dims(x_val, axis=3)),
                callbacks = [es],
                validation_steps = 1
               )
# Out:
# Train on 1848 samples, validate on 528 samples
# Epoch 1/250
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1760 - val_loss: 0.0799
# Epoch 2/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0717 - val_loss: 0.0686
# Epoch 3/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0631 - val_loss: 0.0629
# Epoch 4/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0581 - val_loss: 0.0593
# Epoch 5/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0560 - val_loss: 0.0538
# Epoch 6/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0532 - val_loss: 0.0520
# Epoch 7/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0517 - val_loss: 0.0503
# Epoch 8/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0495 - val_loss: 0.0491
# Epoch 9/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0481 - val_loss: 0.0495
# Epoch 10/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0464 - val_loss: 0.0481
# Epoch 11/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0445 - val_loss: 0.0450
# Epoch 12/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0441 - val_loss: 0.0424
# Epoch 13/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0422 - val_loss: 0.0429
# Epoch 14/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0416 - val_loss: 0.0434
# Epoch 15/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0403 - val_loss: 0.0416
# Epoch 16/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0400 - val_loss: 0.0385
# Epoch 17/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0390 - val_loss: 0.0398
# Epoch 18/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0382 - val_loss: 0.0384
# Epoch 19/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0375 - val_loss: 0.0375
# Epoch 20/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0369 - val_loss: 0.0371
# Epoch 21/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0370 - val_loss: 0.0381
# Epoch 22/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0354 - val_loss: 0.0405
# Epoch 23/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0359 - val_loss: 0.0359
# Epoch 24/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0351 - val_loss: 0.0351
# Epoch 25/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0345 - val_loss: 0.0348
# Epoch 26/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0341 - val_loss: 0.0381
# Epoch 27/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0342 - val_loss: 0.0347
# Epoch 28/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0332 - val_loss: 0.0346
# Epoch 29/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0327 - val_loss: 0.0332
# Epoch 30/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0328 - val_loss: 0.0336
# Epoch 31/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0321 - val_loss: 0.0332
# Epoch 32/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0316 - val_loss: 0.0331
# Epoch 33/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0315 - val_loss: 0.0347
# Epoch 34/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0310 - val_loss: 0.0321
# Epoch 35/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0306 - val_loss: 0.0318
# Epoch 36/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0301 - val_loss: 0.0313
# Epoch 37/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0300 - val_loss: 0.0300
# Epoch 38/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0298 - val_loss: 0.0302
# Epoch 39/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0294 - val_loss: 0.0297
# Epoch 40/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0293 - val_loss: 0.0311
# Epoch 41/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0287 - val_loss: 0.0308
# Epoch 42/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0288 - val_loss: 0.0299
# Epoch 43/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0284 - val_loss: 0.0291
# Epoch 44/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0283 - val_loss: 0.0285
# Epoch 45/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0280 - val_loss: 0.0295
# Epoch 46/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0278 - val_loss: 0.0299
# Epoch 47/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0275 - val_loss: 0.0282
# Epoch 48/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0273 - val_loss: 0.0281
# Epoch 49/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0275 - val_loss: 0.0280
# Epoch 50/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0271 - val_loss: 0.0285
# Epoch 51/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0269 - val_loss: 0.0281
# Epoch 52/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0266 - val_loss: 0.0273
# Epoch 53/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0267 - val_loss: 0.0276
# Epoch 54/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0265 - val_loss: 0.0274
# Epoch 55/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0262 - val_loss: 0.0274
# Epoch 56/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0259 - val_loss: 0.0303
# Epoch 57/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0261 - val_loss: 0.0261
# Epoch 58/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0257 - val_loss: 0.0273
# Epoch 59/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0257 - val_loss: 0.0268
# Epoch 60/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0254 - val_loss: 0.0266
# Epoch 61/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0254 - val_loss: 0.0286
# Epoch 62/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0250 - val_loss: 0.0259
# Epoch 63/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0252 - val_loss: 0.0255
# Epoch 64/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0248 - val_loss: 0.0253
# Epoch 65/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0244 - val_loss: 0.0252
# Epoch 66/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0247 - val_loss: 0.0244
# Epoch 67/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0246 - val_loss: 0.0250
# Epoch 68/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0242 - val_loss: 0.0248
# Epoch 69/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0239 - val_loss: 0.0253
# Epoch 70/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0242 - val_loss: 0.0247
# Epoch 71/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0239 - val_loss: 0.0243
# Epoch 72/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0236 - val_loss: 0.0247
# Epoch 73/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0233 - val_loss: 0.0240
# Epoch 74/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0238 - val_loss: 0.0240
# Epoch 75/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0227 - val_loss: 0.0243
# Epoch 76/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0235 - val_loss: 0.0239
# Epoch 77/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0230 - val_loss: 0.0237
# Epoch 78/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0227 - val_loss: 0.0238
# Epoch 79/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0229 - val_loss: 0.0233
# Epoch 80/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0227 - val_loss: 0.0232
# Epoch 81/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0223 - val_loss: 0.0227
# Epoch 82/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0221 - val_loss: 0.0226
# Epoch 83/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0226 - val_loss: 0.0233
# Epoch 84/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0219 - val_loss: 0.0240
# Epoch 85/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0222 - val_loss: 0.0228
# Epoch 86/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0219 - val_loss: 0.0223
# Epoch 87/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0216 - val_loss: 0.0225
# Epoch 88/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0219 - val_loss: 0.0223
# Epoch 89/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0216 - val_loss: 0.0228
# Epoch 90/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - val_loss: 0.0219
# Epoch 91/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - val_loss: 0.0221
# Epoch 92/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - val_loss: 0.0221
# Epoch 93/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0212 - val_loss: 0.0220
# Epoch 94/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - val_loss: 0.0216
# Epoch 95/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0208 - val_loss: 0.0221
# Epoch 96/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0211 - val_loss: 0.0227
# Epoch 97/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0208 - val_loss: 0.0214
# Epoch 98/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0209 - val_loss: 0.0221
# Epoch 99/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0207 - val_loss: 0.0211
# Epoch 100/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0205 - val_loss: 0.0212
# Epoch 101/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0207 - val_loss: 0.0217
# Epoch 102/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0203 - val_loss: 0.0223
# Epoch 103/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0207 - val_loss: 0.0212
# Epoch 104/250
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0202 - val_loss: 0.0220
# Epoch 00104: early stopping

# %%
fig = plt.figure(figsize=(4,3))
ax = fig.add_subplot(111)

ax.plot(history.history['loss'])
ax.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train Set', 'Validation Set'], loc='upper right')
plt.tight_layout()
plt.show()
#plt.savefig('history.png')

# %%
def show_predicted(track_index, var_index, savefig=False):
    predicted = test_track(data=x_test, model=autoencoder, track_index=track_index, frame_width=15)
    print(predicted.shape)


    fig = plt.figure(figsize=(18,6))
    plt.scatter(range(predicted.shape[0]), predicted[:,var_index], marker='.')
    plt.scatter(range(x_test.shape[1]), x_test[track_index,:,var_index], marker='+')
    plt.legend(('predicted', 'true'))
    if savefig:
        plt.savefig('dim{}.png'.format(INDEX))
        
    plt.grid(b = 150)
    plt.show()
    
    
    
show_predicted(track_index=0, var_index=1)
# Out:
# (495, 3)
